# %% [markdown]
# <a href="https://colab.research.google.com/github/Ncast07/Python_2023/blob/main/10_Seaborn_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Seaborn

# %% [markdown]
# ### ¿Que es Seaborn?
#
# * Es una biblioteca de visualizacion de datos en Python basada en Matplotlib. Y ofrece una interfaz de alto nivel para dibujar graficos.

# %% [markdown]
# * Instalacion en anaconda-jupyter | visual-jupyter
# * pip install seaborn

# %% [markdown]
# ## Importar la Biblioteca:

# %%
#Importar Pandas + Matplotlib + seaborn:

import pandas as pd
import matplotlib as mtp
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Comprendiendo la Sintaxis

# %%
# Estructura Basica

data = {
    'Data en eje X': [1, 2, 3, 4, 5],
    'Data en eje Y': [2, 4, 6, 8, 10],
    'Variable de Agrupamiento': ['A', 'B', 'A', 'B', 'A']
}

DataFrame = pd.DataFrame(data)

sns.scatterplot(
    data=DataFrame,
    x="Data en eje X",
    y="Data en eje Y",
    hue="Variable de Agrupamiento"
)
# Out:
# <Axes: xlabel='Data en eje X', ylabel='Data en eje Y'>

# %% [markdown]
# ### 1. Grafico de Linea

# %%
print('1. Grafico de Linea:')

x=[40,68,77]
y=[15,20,30]

sns.lineplot(x=x,y=y)
plt.show()
# Out:
# 1. Grafico de Linea:

# %% [markdown]
# ### 2. Grafico de Barra

# %%
#Funcion Barra

sns.barplot(    x=['A','B','C'],    y=[1,9,4] )

plt.show()

# %%
#Funcion SET
print("2. Grafico de Barras+ Set")

sns.set(style='darkgrid',palette='dark',font_scale=2)

sns.barplot( x=['A','B','C'], y=[1,9,4] )
plt.show()
# Out:
# 2. Grafico de Barras+ Set

# %% [markdown]
# ### 3. Grafico de Dispersion:

# %%
print("3. Grafico de Dispersion")

x=[40,68,77]
y=[15,20,30]

sns.scatterplot( x=x,y=y)
plt.show()
# Out:
# 3. Grafico de Dispersion

# %% [markdown]
# ### Grafico de Histograma

# %%
print("4. Grafico de Histograma")

x=[1,3,3,3,3,3,5,7,89,88,88,88,88,88,88,40,40,40,40,40,40,40,40,40,6,1,8,7,1,5,74,1,3,1]

sns.histplot(x=x, bins=10)
plt.show()
# Out:
# 4. Grafico de Histograma

# %% [markdown]
# #Utilizando un DataFrame de Seaborn

# %%
propinas = sns.load_dataset('tips')

# %%
propinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
propinas.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Grafico Displot

# %%
#Grafico Displot Distribución:
sns.displot(
    data=propinas,
    x='total_bill')
plt.show()
